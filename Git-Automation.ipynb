# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle Data Sets/"
# %cd /content/gdrive/My Drive/gitAutomation/
# Out:
# /content/gdrive/My Drive/ML Project

# %%
# !ls
# Out:
#  anaaf.py  'ML Project Data Analysis.ipynb'

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML Project/.git/

# %%
# !git branch -M main

# %%
# !git remote add origin https://<usernaem>:<password>@github.com/<username>/<repo-name>.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://anaaf:dontbelieveinluck@github.com/anaaf/test-repo.git (fetch)
# origin	https://anaaf:dontbelieveinluck@github.com/anaaf/test-repo.git (push)

# %%
# to remove remote origin
# !git remote rm origin

# %%
# !git remote set-url origin https://github.com/anaaf/test-repo.git

# %%
# !git config --global user.email '<email-id>'
# !git config --global user.name '<username>'

# %%
# !git add <filname>
# !git add . # for all files
# !git add -A # all files (for google colab notebook)

# %%
# !git status # to check the status (are files commited or the branch is empty)
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git commit -m '<commit-test/msg>'
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git push -u origin main
# Out:
# remote: Repository not found.
# fatal: repository 'https://anaaf:dontbelieveinluck@github.com/anaaf/test-repo.git/' not found
