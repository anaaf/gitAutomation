# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
# connect project file from google drive
# %cd /content/gdrive/My Drive/<project-folder>/
# Out:
# /content/gdrive/My Drive/ML Project

# %%
# !ls
# Out:
#  anaaf.py  'ML Project Data Analysis.ipynb'

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ML Project/.git/

# %%
# !git config --global user.email '<email-id>'
# !git config --global user.name '<username>'

# %%
# adding files
# !git add <filname>
# !git add . # for all files

# %%
# commiting changes
# !git commit -m '<commit-test/msg>'

# %%
# connecting the remote remo into colab
# !git remote add origin https://<username>:<password>@github.com/<username>/<repo-name>.git

# %%
# push the changes to remote repo
# !git push -u origin main

# %% [markdown]
# ## Some hacks and other commands of git

# %%
# to remove remote origin
# !git remote rm origin

# %%
# to explicitly set url if  "!git remote add origin https://<username>:<password>@github.com/<username>/<repo-name>.git" doesnt work

# !git remote set-url origin https://github.com/anaaf/test-repo.git

# %%
# to check the status (are files commited or the branch is empty)

# !git status
